# %% [markdown]
# <a href="https://colab.research.google.com/github/j-see17/Python-Coding/blob/main/Copy_of_BUMK744_Hierarchical_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hierarchical Quiz**
# *BUMK744 Marketing Research and Analytics*

# %% [markdown]
# **Notes**
# - Save your notebook often, in case you get disconnected or the Google Colab environment crashes.
# - Save a copy of your notebook.
# - You **need to submit** your notebook along with your canvas quiz.
# - Provide all your answers in 4 decimals precision.

# %% [markdown]
# Run the cell below to load the standard packages and the dataset stored in the variable **`X`**
# * **You should use the `X` matrix as is. Do not perform any additional transformations on `X` unless specifically instructed!**

# %%
import numpy as np
import pandas as pd

# plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

url = 'https://raw.githubusercontent.com/brunojacobs/BUMK744/master/data/cars.csv'
cars = pd.read_csv(url)
cars = cars.set_index('Carname')
X = (cars - cars.mean()) / cars.std()

print('Head of dataframe:')
print(X.head(), '\n')

print('Means:')
print(X.mean().round(6), '\n')

print('Variances:')
print(X.var().round(6))
# Out:
# Head of dataframe:
#                         mpg      disp        hp      drat        wt      qsec
# Carname
# Mazda RX4          0.150885 -0.570620 -0.535093  0.567514 -0.610400 -0.777165
# Mazda RX4 Wag      0.150885 -0.570620 -0.535093  0.567514 -0.349785 -0.463781
# Datsun 710         0.449543 -0.990182 -0.783040  0.474000 -0.917005  0.426007
# Hornet 4 Drive     0.217253  0.220094 -0.535093 -0.966118 -0.002300  0.890487
# Hornet Sportabout -0.230735  1.043081  0.412942 -0.835198  0.227654 -0.463781
#
# Means:
# mpg    -0.0
# disp    0.0
# hp      0.0
# drat   -0.0
# wt     -0.0
# qsec   -0.0
# dtype: float64
#
# Variances:
# mpg     1.0
# disp    1.0
# hp      1.0
# drat    1.0
# wt      1.0
# qsec    1.0
# dtype: float64

# %% [markdown]
# **Adapt the code (!!!)** in the code cell below to apply **agglomerative hierarchical clustering** on the standardized data `X`.
#
# **Carefully follow these instructions**:
# - Define distance between clusters as the **maximum distance (!!!) between a pair of observations**
# - Perform the clustering using the **`linkage`** method from **``scipy``**
# - Visualize the hierarchy in a **dendrogram** using the **`dendrogram`** function from scipy

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# IMPORTANT: incomplete code, adapt it!

Z = pd.DataFrame(linkage(X))

fig = plt.figure(figsize=(15, 10))
plt.xlabel('Cluster distance')
dn = dendrogram(Z, orientation='right', labels=X.index, color_threshold=0)
plt.show()

# %% [markdown]
# # Question 5
#
# **Using the dendrogram**, what is the **Euclidean distance** between the `Valiant` and `Hornet 4 Drive` cars? **Round your answer to the nearest integer**, i.e. whole number.
#
# **Note**: Your answer should be rounded to the **closest integer**, i.e. a whole number without a fractional component. For example, if your answer is 4.52, provide the answer 5

# %% [markdown]
# # Question 6
#
# **Based on the dendrogram**, from the cars listed below, which one is **most similar** to the `Toyota Corolla`?
#
# Choose from:
# > - Ferrari Dino
# > - Pontiac Firebird
# > - Porsche 914-2
# > - Toyota Corona

# %% [markdown]
# # Question 7
#
# If a researcher specifies a **maximum cluster distance of 4.5**, what is the **`smallest`** number of clusters that can be created **based on the dendrogram**?
#
# **`Note`**: Your answer should be an integer, i.e., a whole number without a fractional component. For example, if your answer is 7 clusters, provide **7** as your answer
